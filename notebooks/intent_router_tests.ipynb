# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path("..").resolve()

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from graph.workflow import build_workflow

app = build_workflow()

# %%
state = {
    "question": 'What is the process to add a new upstream system?',
    "steps": []
}

result = app.invoke(state)
print(result["steps"])

# %%
state = {
    "question": 'Spark executor memory tuning best practices',
    "steps": []
}

result = app.invoke(state)
print(result["steps"])

# %%
state = {
    "question": 'Terminal command not working',
    "steps": []
}

result = app.invoke(state)
print(result["steps"])

# %%
state = {
    "question": "Can't copy to AZ location",
    "steps": []
}

result = app.invoke(state)
print(result["steps"])

# %%
state = {
    "question": "Airflow DAG failing with exit code 137",
    "steps": []
}

result = app.invoke(state)
print(result["steps"])

# %% [markdown]
# #### This should be an SOP Query

# %%
state = {
    "question": "How do I configure Spark job retries?",
    "steps": []
}

result = app.invoke(state)
print(result["steps"])

# %%
state = {
    "question": "What should be done before enabling a new feed?",
    "steps": []
}

result = app.invoke(state)
print(result["steps"])

# %%
state = {
    "question": "Disk keeps filling up on the server",
    "steps": []
}

result = app.invoke(state)
print(result["steps"])

# %% [markdown]
# #### This should be an SOP Query

# %%
state = {
    "question": "Who owns the ingestion pipeline for payments data?",
    "steps": []
}

result = app.invoke(state)
print(result["steps"])

# %% [markdown]
# ### FAIL !

# %%
state = {
    "question": "Error budget policy for data platform",
    "steps": []
}

result = app.invoke(state)
print(result["steps"])

# %% [markdown]
# #### FAIL !

# %%
state = {
    "question": "Spark onboarding checklist",
    "steps": []
}

result = app.invoke(state)
print(result["steps"])

# %%
state = {
    "question": "How does Spark handle shuffle failures internally?",
    "steps": []
}

result = app.invoke(state)
print(result["steps"])

# %%
state = {
    "question": "Best practices for data platform",
    "steps": []
}

result = app.invoke(state)
print(result["steps"])
